# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %%
#Load matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
#To plot a curve

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values') #define your x and y a-xis, color of plot, linestyle, and label for line
plt.xlabel('x-values') #x-axis label
plt.ylabel('y-values') #y-axis label
plt.title('X vs Y') #graph title
plt.grid(alpha=.25) #grids and the boldness of the grid
plt.legend(loc='upper left') #where to put the legend
plt.show() #show the plotted graph

# %% [markdown]
# You can use the following abbreviation
#
# | **Long form** | **Abbreviation** |
# |:-------------:|:----------------:|
# |     color     |         c        |
# |   linestyle   |        ls        |
# |   linewidth   |        lw        |

# %%
#Both the following lines produce the same result

plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)
plt.plot(x, y, c='red', ls='dashed', lw=2)

# %% [markdown]
# Although you will still see an output even if you omit plt.show() in Jupyter as it is an interactive environment, it is good practice to include this line anayway so that the code will also work in non-interactive environments
#
# Plotting functions usually have default values for styling parameters. So you can keep a plot simple as follows:

# %%
plt.plot(x, y)

# %% [markdown]
# ### 1.2 Adding another plot

# %%
#Can add another plot command to the graph to plot the data of y_2 in blue by adding the following line

plt.plot(x, y_2, color='blue', label='Y2 values')

# %%
#To have two graphs in the same plot:
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
#To add a plot that includes x and y error bars for the points, the plotting command to use is called errorbar()

#plt.errorbar(x, y_3, xerr = x_error, yerr = y_error, color = "green", label = "Y3 with errors")

# %%
#Combining the three plots:
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, color='green', label='Y3 with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
#Visit colorBrewer and pick other colours for the lines
plt.plot(x, y_1, color='#8856a7', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='#2b8cbe', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, color='#31a354', label='Y3 with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y', color = '#bdbdbd') #Change color of title
plt.grid(alpha=.75, color = '#fde0dd', linestyle = 'dashed') #Change the vlaue of alpha and specify more options for grid
plt.legend(loc='center') #Changed loc of legend to center
plt.show()

#For the location of the legend:
#'bottom left' is not a valid value for loc; supported values are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'
#if you do not specify a location, the default value is 'upper left'

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
#It is often easier to use NumPy arrays instead of Python list
#Hence, will first convert Python lists into NumPy arrays and redo the plot

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
#One advantage of NumPy arrays is that it allows us to easily generate data-relataed maths functions
#Reusing our previous code to plot x**2 and sin(x)

x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend()
plt.show()

# %% [markdown]
# Plot does not look good because sin(x) lies between +-1 but x^2 has no such bounds. One way to fix this is to add another y-axis that shares the same x-axis

# %% [markdown]
# ### 1.7 We need another axis!

# %%
#matplotlib offers a variety of ways to have multiple axes
#Simplest way to have another y-axis that shares the same x-axis is to use the command twinx():

x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# **Note** that we have two legend() calls, one for each axis.
#
# However, plot still does not look good because we have limited points. Can use np.linspace to fix this with:

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# Documentation of numpy.linspace
#
# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
#
# Return evenly spaced numbers over a specified interval.

# %% [markdown]
# ### 1.8 Saving to disc

# %% [markdown]
# To use a plot in a report or presentation, you must first save it to disk. matplotlib makes it easy to export plots into many formats (PDF, JPEG, PNG, BMP...) and at different resolutions.
#
# To do this, we use the function savefig() and specify the format with the extension (e.g. filename.pdf) of the file name and resolution by specifying the dots-per-inch (dpi)

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

#This will save the file in the same directory as the one my notebook is in.
#Can specify the path in more detail for e.g.
#plt.savefig('~/Desktop/simple-plot.png', dpi=150)

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
#Need to know how to plot data stored in a file (e.g. spreadsheet, text file , database)

#Using average temperature data for Daily Land in the Berkeley Earth website
#Loaading the txt file into data
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0] #accessing date from data
anomaly = data[:, -1] #accessing anomaly from data

#plot
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
# Out:
# (-8.0, 8.0)

# %%
#To add a horizontal line at the zero value to highlight the trend shown by the data
#hlines() function needs a y-value and starting and ending values for x
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])

plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %%
#matplotlib offers some standard style templates

#to use the fivethirtyeight style template

plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %%
#to use default style, just perform:
plt.style.use('default')

# %% [markdown]
# ### 2.2 xkcd!

# %%
#matplotlib has xkcd style for fun
#just run plt.xkcd() to enable it
# will not run it as I do not have 'Humor Sans' installed and it will cause my subsequent plots to be in xkcd

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
# Some data for plotting
plt.style.use('default')

x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, xerr= x_err, yerr= y_err,
             color= 'red', linestyle= 'dashed',
             marker= 'o', markerfacecolor= 'yellow',
             ecolor= 'black',capsize=5,
             label= 'Y values with error')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc = 'lower right')
#save_file_figure(plt, argv)                  # Hide
plt.show(block=False)

# %% [markdown]
# ## Exercise 2 :  A simple mathematical plot

# %%
plt.style.use('default')

x = np.linspace(0, 50, 1000)
y = np.sin(x) * (np.e**(-x/10))

plt.plot(x, y)
plt.xlabel('x-values', fontsize=15, color = 'darkblue')
plt.ylabel('y-values', fontsize=15, color = 'darkblue')
plt.grid(alpha=.25)
plt.title(r'$y = e^{-x/10}\sin(x)$', fontsize=20)
plt.ylim([-1, 1])
plt.show()
